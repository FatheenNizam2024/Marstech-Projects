# %%
import pandas as pd
import numpy as np

# %%
dataset = pd.read_csv("Concrete Strength.csv")

# %%
dataset.columns
# Out:
# Index(['Cement (component 1)(kg in a m^3 mixture)',
#        'Blast Furnace Slag (component 2)(kg in a m^3 mixture)',
#        'Fly Ash (component 3)(kg in a m^3 mixture)',
#        'Water  (component 4)(kg in a m^3 mixture)',
#        'Superplasticizer (component 5)(kg in a m^3 mixture)',
#        'Coarse Aggregate  (component 6)(kg in a m^3 mixture)',
#        'Fine Aggregate (component 7)(kg in a m^3 mixture)', 'Age (day)',
#        'Concrete compressive strength(MPa, megapascals) '],
#       dtype='object')

# %%
independent = dataset[['Cement (component 1)(kg in a m^3 mixture)',
       'Blast Furnace Slag (component 2)(kg in a m^3 mixture)',
       'Fly Ash (component 3)(kg in a m^3 mixture)',
       'Water  (component 4)(kg in a m^3 mixture)',
       'Superplasticizer (component 5)(kg in a m^3 mixture)',
       'Coarse Aggregate  (component 6)(kg in a m^3 mixture)',
       'Fine Aggregate (component 7)(kg in a m^3 mixture)', 'Age (day)']]

# %%
dependent = dataset[['Concrete compressive strength(MPa, megapascals) ']]

# %%
independent
# Out:
#       Cement (component 1)(kg in a m^3 mixture)  \
# 0                                         540.0
# 1                                         540.0
# 2                                         332.5
# 3                                         332.5
# 4                                         198.6
# ...                                         ...
# 1025                                      276.4
# 1026                                      322.2
# 1027                                      148.5
# 1028                                      159.1
# 1029                                      260.9
#
#       Blast Furnace Slag (component 2)(kg in a m^3 mixture)  \
# 0                                                   0.0
# 1                                                   0.0
# 2                                                 142.5
# 3                                                 142.5
# 4                                                 132.4
# ...

# %%
dependent
# Out:
#       Concrete compressive strength(MPa, megapascals)
# 0                                                79.99
# 1                                                61.89
# 2                                                40.27
# 3                                                41.05
# 4                                                44.30
# ...                                                ...
# 1025                                             44.28
# 1026                                             31.18
# 1027                                             23.70
# 1028                                             32.77
# 1029                                             32.40
#
# [1030 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(independent,dependent,train_size = 0.90, random_state = 0)

# %%
x_train
# Out:
#      Cement (component 1)(kg in a m^3 mixture)  \
# 957                                      143.0
# 267                                      212.0
# 863                                      288.0
# 342                                      297.2
# 416                                      213.5
# ..                                         ...
# 277                                      251.4
# 763                                      385.0
# 835                                      144.0
# 559                                      239.6
# 684                                      192.0
#
#      Blast Furnace Slag (component 2)(kg in a m^3 mixture)  \
# 957                                              169.4
# 267                                                0.0
# 863                                              121.0
# 342                                                0.0
# 416                                                0.0
# ..                                                 ...
# ...

# %%
#from sklearn.preprocessing import StandardScaler
#sc=StandardScaler()
#x_train=sc.fit_transform(x_train)#transformation of x_train using StandardScaler
#x_test=sc.transform(x_test)

# %%
#x_train

# %%
#from sklearn.svm import SVR
#regressor=SVR(C=7000000.0)
#regressor.fit(x_train,y_train) #to train the model

# %%
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
regressor.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
weight = regressor.coef_

# %%
weight
# Out:
# array([[ 0.12060184,  0.1080986 ,  0.08966115, -0.13554582,  0.35264901,
#          0.02365182,  0.02204194,  0.11202835]])

# %%
bais = regressor.intercept_

# %%
bais
# Out:
# array([-33.72422679])

# %%
ypred = regressor.predict(x_test)

# %%
ypred
# Out:
# array([[39.92361304],
#        [14.4404402 ],
#        [61.37360548],
#        [53.51863976],
#        [24.37589014],
#        [54.08312209],
#        [46.27319441],
#        [26.99303228],
#        [53.31377422],
#        [37.70159565],
#        [16.87364662],
#        [39.0192799 ],
#        [29.43361435],
#        [35.72916248],
#        [48.07750418],
#        [56.71284856],
#        [35.36552721],
#        [29.39800568],
#        [48.85553712],
#        [35.06688632],
#        [53.43326734],
#        [32.15282136],
#        [32.46410615],
#        [48.4074237 ],
#        [23.71585531],
#        [23.60172988],
#        [70.00103038],
#        [26.36733032],
#        [56.71284856],
#        [48.20458424],
#        [18.98507356],
#        [36.67054526],
#        [17.58093143],
#        [20.19816296],
#        [24.77142985],
#        [15.26968836],
#        [53.63500868],
#        [27.70303205],
#        [27.33260738],
#        [25.87414885],
#        [52.71055984],
# ...

# %%
from sklearn.metrics import r2_score

# %%
r_score = r2_score(y_test,ypred)

# %%
r_score
# Out:
# 0.6130673777738749

# %%
import pickle

# %%
my_model = ("concrete strength predic.sav")

# %%
pickle.dump(regressor,open(my_model,'wb'))
