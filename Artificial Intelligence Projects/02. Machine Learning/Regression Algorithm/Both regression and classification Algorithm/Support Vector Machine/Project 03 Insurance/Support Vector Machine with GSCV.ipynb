# %%
import pandas as pd
import numpy as np
#import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv("Artificial_Intelligence_Assignment_06_dataset_insurance_pre.csv")

# %%
dataset = pd.get_dummies(dataset, drop_first=True)

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400     False        True
# 1      18  33.770         1   1725.55230      True       False
# 2      28  33.000         3   4449.46200      True       False
# 3      33  22.705         0  21984.47061      True       False
# 4      32  28.880         0   3866.85520      True       False
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830      True       False
# 1334   18  31.920         0   2205.98080     False       False
# 1335   18  36.850         0   1629.83350     False       False
# 1336   21  25.800         0   2007.94500     False       False
# 1337   61  29.070         0  29141.36030     False        True
#
# [1338 rows x 6 columns]

# %%
independent = dataset[['age','bmi','children','sex_male', 'smoker_yes']]

# %%
dependent = dataset[['charges']]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(independent,dependent,train_size=0.70,random_state=0)

# %%
#Model creation for SVM_(Support Vector Machine)_Regression_with_GSCV
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR
param_grid = {'kernel':['rbf','poly','sigmoid','linear'],'C':[10,100,1000,2000,3000],'degree':[3],'gamma':['scale'],'coef0':[0.0],
             'tol':[1e-3],'epsilon':[0.1], 'shrinking':[True],'cache_size':[200],'verbose':[False],'max_iter':[-1]}

grid = GridSearchCV(SVR(), param_grid, refit=True, verbose=3,n_jobs=-1)

#fitting the model for gridsearchcv

grid.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# C:\Python312\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GridSearchCV(estimator=SVR(), n_jobs=-1,
#              param_grid={'C': [10, 100, 1000, 2000, 3000], 'cache_size': [200],
#                          'coef0': [0.0], 'degree': [3], 'epsilon': [0.1],
#                          'gamma': ['scale'],
#                          'kernel': ['rbf', 'poly', 'sigmoid', 'linear'],
#                          'max_iter': [-1], 'shrinking': [True], 'tol': [0.001],
#                          'verbose': [False]},
#              verbose=3)

# %%
#print best parameter after tuning
#print(grid.best_params_)
re = grid.cv_results_

print("The R_Score value for best parameter {}:".format(grid.best_params_))
# Out:
# The R_Score value for best parameter {'C': 2000, 'cache_size': 200, 'coef0': 0.0, 'degree': 3, 'epsilon': 0.1, 'gamma': 'scale', 'kernel': 'linear', 'max_iter': -1, 'shrinking': True, 'tol': 0.001, 'verbose': False}:

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_C  \
# 0        0.064218      0.001918         0.035488        0.002375       10
# 1        0.056590      0.005245         0.011897        0.000776       10
# 2        0.081245      0.006429         0.018832        0.001294       10
# 3        0.065025      0.003529         0.010150        0.000751       10
# 4        0.056859      0.001056         0.034677        0.001062      100
# 5        0.062772      0.005810         0.010324        0.000752      100
# 6        0.074646      0.002879         0.017352        0.001190      100
# 7        0.165478      0.040850         0.009988        0.000907      100
# 8        0.070686      0.006954         0.034344        0.000942     1000
# 9        0.088532      0.007851         0.010203        0.000375     1000
# 10       0.078466      0.004766         0.017851        0.001358     1000
# 11       0.647223      0.076307         0.008634        0.001121     1000
# 12       0.073356      0.002291         0.034599        0.001268     2000
# 13       0.127164      0.018093         0.010652        0.001502     2000
# 14       0.073932      0.003159         0.017732        0.001236     2000
# 15       0.983049      0.083159         0.008218        0.001800     2000
# 16       0.077248      0.007532         0.035008        0.002318     3000
# 17       0.137785      0.010993         0.014185        0.008874     3000
# 18       0.081334      0.012311         0.017726        0.000928     3000
# 19       2.006056      1.179840         0.009371        0.003623     3000
#
#     param_cache_size  param_coef0  param_degree  param_epsilon param_gamma  \
# 0                200          0.0             3            0.1       scale
# 1                200          0.0             3            0.1       scale
# 2                200          0.0             3            0.1       scale
# 3                200          0.0             3            0.1       scale
# 4                200          0.0             3            0.1       scale
# 5                200          0.0             3            0.1       scale
# 6                200          0.0             3            0.1       scale
# 7                200          0.0             3            0.1       scale
# 8                200          0.0             3            0.1       scale
# 9                200          0.0             3            0.1       scale
# 10               200          0.0             3            0.1       scale
# 11               200          0.0             3            0.1       scale
# 12               200          0.0             3            0.1       scale
# 13               200          0.0             3            0.1       scale
# 14               200          0.0             3            0.1       scale
# 15               200          0.0             3            0.1       scale
# 16               200          0.0             3            0.1       scale
# 17               200          0.0             3            0.1       scale
# 18               200          0.0             3            0.1       scale
# 19               200          0.0             3            0.1       scale
#
#     ... param_verbose                                             params  \
# 0   ...         False  {'C': 10, 'cache_size': 200, 'coef0': 0.0, 'de...
# 1   ...         False  {'C': 10, 'cache_size': 200, 'coef0': 0.0, 'de...
# 2   ...         False  {'C': 10, 'cache_size': 200, 'coef0': 0.0, 'de...
# 3   ...         False  {'C': 10, 'cache_size': 200, 'coef0': 0.0, 'de...
# 4   ...         False  {'C': 100, 'cache_size': 200, 'coef0': 0.0, 'd...
# 5   ...         False  {'C': 100, 'cache_size': 200, 'coef0': 0.0, 'd...
# 6   ...         False  {'C': 100, 'cache_size': 200, 'coef0': 0.0, 'd...
# 7   ...         False  {'C': 100, 'cache_size': 200, 'coef0': 0.0, 'd...
# 8   ...         False  {'C': 1000, 'cache_size': 200, 'coef0': 0.0, '...
# 9   ...         False  {'C': 1000, 'cache_size': 200, 'coef0': 0.0, '...
# 10  ...         False  {'C': 1000, 'cache_size': 200, 'coef0': 0.0, '...
# 11  ...         False  {'C': 1000, 'cache_size': 200, 'coef0': 0.0, '...
# 12  ...         False  {'C': 2000, 'cache_size': 200, 'coef0': 0.0, '...
# 13  ...         False  {'C': 2000, 'cache_size': 200, 'coef0': 0.0, '...
# 14  ...         False  {'C': 2000, 'cache_size': 200, 'coef0': 0.0, '...
# 15  ...         False  {'C': 2000, 'cache_size': 200, 'coef0': 0.0, '...
# 16  ...         False  {'C': 3000, 'cache_size': 200, 'coef0': 0.0, '...
# 17  ...         False  {'C': 3000, 'cache_size': 200, 'coef0': 0.0, '...
# 18  ...         False  {'C': 3000, 'cache_size': 200, 'coef0': 0.0, '...
# 19  ...         False  {'C': 3000, 'cache_size': 200, 'coef0': 0.0, '...
#
#     split0_test_score  split1_test_score  split2_test_score split3_test_score  \
# 0           -0.045477          -0.013336          -0.151791         -0.151967
# 1           -0.134216           0.026782          -0.212979         -0.237453
# 2           -0.042877          -0.039512          -0.150154         -0.138492
# 3           -0.099849           0.109498          -0.136196         -0.141381
# 4           -0.158546           0.013775          -0.243127         -0.254520
# 5           -0.176499           0.036989          -0.230291         -0.265222
# 6           -0.059561          -0.063480          -0.155368         -0.152757
# 7            0.477795           0.582292           0.432079          0.458983
# 8           -0.191422           0.021962          -0.246590         -0.264813
# 9           -0.159610           0.073940          -0.191657         -0.222295
# 10          -1.141295          -1.269703          -1.074688         -1.221982
# 11           0.592288           0.663607           0.559347          0.582636
# 12          -0.188138           0.029758          -0.237425         -0.256760
# 13          -0.125105           0.110725          -0.147396         -0.179032
# 14          -4.204699          -4.639898          -3.600431         -4.265575
# 15           0.600340           0.664454           0.564693          0.618692
# 16          -0.182267           0.038588          -0.228062         -0.245915
# 17          -0.089247           0.147471          -0.105647         -0.135930
# 18          -9.347820         -10.015654          -7.896694         -9.548932
# 19           0.600282           0.600528           0.571175          0.562946
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0           -0.139448        -0.100404        0.059028                8
# 1           -0.159582        -0.143490        0.092731               12
# 2           -0.143396        -0.102886        0.050518                9
# 3           -0.075432        -0.068672        0.092313                6
# 4           -0.166782        -0.161840        0.095993               15
# 5           -0.171039        -0.161212        0.105075               14
# 6           -0.160115        -0.118256        0.046401               10
# 7            0.439511         0.478132        0.054459                4
# 8           -0.174935        -0.171160        0.102158               17
# 9           -0.140164        -0.127957        0.104757               11
# 10          -1.154634        -1.172460        0.067464               18
# 11           0.558849         0.591345        0.038415                2
# 12          -0.168701        -0.164253        0.102120               16
# 13          -0.101751        -0.088512        0.102831                7
# 14          -3.612375        -4.064596        0.402727               19
# 15           0.563567         0.602349        0.037550                1
# 16          -0.161880        -0.155907        0.101849               13
# 17          -0.063951        -0.049461        0.101202                5
# 18          -7.664412        -8.894703        0.938030               20
# 19           0.565766         0.580139        0.016757                3
#
# [20 rows x 24 columns]

# %%
table.to_csv("best_parameters.csv", index=False)

# %%
#from reportlab.lib.pagesizes import letter
#from reportlab.pdfgen import canvas

# Sample DataFrame
#data = {'Parameter': ['max_depth', 'min_samples_split', 'min_samples_leaf'],
 #       'Best Value': [10, 2, 1]}
#table = pd.DataFrame(data)

# Function to convert DataFrame to PDF
#def table_to_pdf(table, filename="output.pdf"):
 #   c = canvas.Canvas(filename, pagesize=letter)
  #  width, height = letter
   # c.setFont("Helvetica", 10)

#    x_offset = 50
 #   y_offset = height - 50
  #  line_height = 20
#
   # Draw column headers
   # for col_index, col_name in enumerate(table.columns):
 #       c.drawString(x_offset + col_index * 100, y_offset, col_name)

  #  y_offset -= line_height

    # Draw table rows
   # for row in table.itertuples(index=False):
    #    for col_index, value in enumerate(row):
     #       c.drawString(x_offset + col_index * 100, y_offset, str(value))
      #  y_offset -= line_height

#        if y_offset < 50:  # Start a new page if needed
 #           c.showPage()
  #          y_offset = height - 50

   # c.save()
    #print(f"PDF saved as {filename}")

# Convert DataFrame to PDF
#table_to_pdf(table, "best_parameters.pdf")

# %%
y_pred=grid.predict(x_test)

# %%
from sklearn.metrics import r2_score
r_score=r2_score(y_test,y_pred)

# %%
r_score
# Out:
# 0.6893263105100382

# %%
import pickle

# %%
mymodel= ("SVR Insurance.sav")

# %%
pickle.dump(grid,open(mymodel,'wb'))
